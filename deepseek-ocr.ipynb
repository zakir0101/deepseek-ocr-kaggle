# %%
# !rm /kaggle/working/DeepSeek-OCR -rf

# %%
# !git clone https://github.com/zakir0101/deepseek-ocr-kaggle.git

# %%
# %cd /kaggle/working/deepseek-ocr-kaggle
# !git pull
# !git status

# %%
# %cd /kaggle/working/deepseek-ocr-kaggle


# Setup (run once)
# !python kaggle_setup.py

# %%
# %cd /kaggle/working/deepseek-ocr-kaggle
# !git pull
# !git status

# Runtime (run whenever)
# !python kaggle_server.py
